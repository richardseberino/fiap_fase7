# %% [markdown]
# <a href="https://colab.research.google.com/github/richardseberino/fiap_fase6_cap1/blob/main/Entrega2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrega 2 - Redes Neurais
#
# Usando o modelo de redes neurais YOLO para treinar e testar o recomnhecimento das imagens de duas categorias diferentes

# %% [markdown]
# ## 1 - Preparação

# %% [markdown]
# ### 1.1 Conectar ao Google Drive
# Aqui é um passo impoartante para dar acesso ao repositório onde as imagens para treinamento estão

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.2 - Baixar o repo do projeto YoloV5

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# ### 1.3 - Instalar as dependencias

# %%
! pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 80.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2 - Treinar o modelo

# %% [markdown]
# ## 2.1 - Inciar o treinamento

# %%
# !python yolov5/train.py --data drive/MyDrive/fiap/fase6/classes.yaml --weights yolov5s.pt --img 640 --epochs 40
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-13 02:06:45.509032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760321205.528560    7193 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760321205.534492    7193 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760321205.549557    7193 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # 3 - Testando o modelo

# %% [markdown]
# ## 3.1 - Testando com arquivos de exemplos
# Aqui vamos usar uma pasta chamada test com arquivos inéditos que o modelos ainda não viu

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/fiap/fase6/images/test/ --data drive/MyDrive/fiap/fase6/classes.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/fiap/fase6/images/test/ --data drive/MyDrive/fiap/fase6/classes.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")
# Out:
# detect: weights=['yolov5/runs/train/exp3/weights/best.pt'], source=drive/MyDrive/fiap/fase6/images/test/, data=drive/MyDrive/fiap/fase6/classes.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/10 /content/drive/MyDrive/fiap/fase6/images/test/IMG-20251012-WA0003.jpg: 640x640 1 garfo, 11.4ms
# image 2/10 /content/drive/MyDrive/fiap/fase6/images/test/IMG-20251012-WA0013.jpg: 640x640 1 garfo, 11.4ms
# ...
